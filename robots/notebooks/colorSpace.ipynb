# %% [markdown]
# <a href="https://colab.research.google.com/github/jumbokh/csu1111-class/blob/main/robots/notebooks/colorSpace.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#RGB<->GRAY
import cv2
lena=cv2.imread("lenacolor.png")
gray=cv2.cvtColor(lena,cv2.COLOR_BGR2GRAY)
rgb=cv2.cvtColor(gray,cv2.COLOR_GRAY2BGR)
#==========打印shape============
print("lena.shape=",lena.shape)
print("gray.shape=",gray.shape)
print("rgb.shape=",rgb.shape)
# Out:
# lena.shape= (512, 512, 3)
# gray.shape= (512, 512)
# rgb.shape= (512, 512, 3)

# %%
#==========显示效果============
from google.colab.patches import cv2_imshow
cv2_imshow(lena)
cv2_imshow(gray)
cv2_imshow(rgb)
#cv2.waitKey()
#cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F2329C19F50>
# <PIL.Image.Image image mode=L size=512x512 at 0x7F2329B99B50>
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F2329B94C50>

# %%
## ex5
import cv2
from google.colab.patches import cv2_imshow
lena=cv2.imread("lenacolor.png")
rgb = cv2.cvtColor(lena, cv2.COLOR_BGR2RGB)
cv2_imshow(lena)
cv2_imshow(rgb)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F2328B3B2D0>
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F2328B3B490>
