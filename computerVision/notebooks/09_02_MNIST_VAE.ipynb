# %% [markdown]
# <a href="https://colab.research.google.com/github/jumbokh/csu1111-class/blob/main/computerVision/notebooks/09_02_MNIST_VAE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 以MNIST資料集訓練VAE模型，並生成影像

# %%
# 載入相關套件
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Input, Dense, Lambda
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from scipy.stats import norm

# %% [markdown]
# ## 取得 MNIST 訓練資料

# %%
# 取得 MNIST 訓練資料
(x_tr, y_tr), (x_te, y_te) = mnist.load_data()
x_tr, x_te = x_tr.astype('float32')/255., x_te.astype('float32')/255.
x_tr, x_te = x_tr.reshape(x_tr.shape[0], -1), x_te.reshape(x_te.shape[0], -1)
print(x_tr.shape, x_te.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 1s 0us/step
# (60000, 784) (10000, 784)

# %% [markdown]
# ## 定義編碼器模型

# %%
# 超參數設定
batch_size, n_epoch = 100, 100  # 訓練執行批量、週期
n_hidden, z_dim = 256, 2        # 編碼器隱藏層神經元個數、輸出層神經元個數

# %%
# encoder
x = Input(shape=(x_tr.shape[1:]))
x_encoded = Dense(n_hidden, activation='relu')(x)
x_encoded = Dense(n_hidden//2, activation='relu')(x_encoded)

# encoder 後接 Dense，估算平均數 mu
mu = Dense(z_dim)(x_encoded)

# encoder 後接 Dense，估算 log 變異數 log_var
log_var = Dense(z_dim)(x_encoded)

# %% [markdown]
# ## 定義抽樣函數

# %%
# 定義抽樣函數
def sampling(args):
    # 根據 mu, log_var 取隨機亂數
    mu, log_var = args
    eps = K.random_normal(shape=(batch_size, z_dim), mean=0., stddev=1.0)
    return mu + K.exp(log_var) * eps

# 定義匿名函數，進行抽樣
z = Lambda(sampling, output_shape=(z_dim,))([mu, log_var])

# %% [markdown]
# ## 定義解碼器模型

# %%
# decoder
z_decoder1 = Dense(n_hidden//2, activation='relu')
z_decoder2 = Dense(n_hidden, activation='relu')
y_decoder = Dense(x_tr.shape[1], activation='sigmoid')

# 解碼的輸入為匿名函數
z_decoded = z_decoder1(z)
z_decoded = z_decoder2(z_decoded)
y = y_decoder(z_decoded)

# %% [markdown]
# ## 定義特殊的損失函數(loss)

# %%
# 定義特殊的損失函數(loss)
reconstruction_loss = tf.keras.losses.binary_crossentropy(x, y) * x_tr.shape[1]
kl_loss = 0.5 * K.sum(K.square(mu) + K.exp(log_var) - log_var - 1, axis = -1)
vae_loss = reconstruction_loss + kl_loss

vae = Model(x, y)   # x:MNIST圖像， y:解碼器的輸出
vae.add_loss(vae_loss)
vae.compile(optimizer='rmsprop')

# 顯示模型彙總資訊
vae.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 784)]        0           []
#
#  dense (Dense)                  (None, 256)          200960      ['input_1[0][0]']
#
#  dense_1 (Dense)                (None, 128)          32896       ['dense[0][0]']
#
#  dense_2 (Dense)                (None, 2)            258         ['dense_1[0][0]']
#
#  dense_3 (Dense)                (None, 2)            258         ['dense_1[0][0]']
#
#  lambda (Lambda)                (100, 2)             0           ['dense_2[0][0]',
#                                                                   'dense_3[0][0]']
#
#  dense_4 (Dense)                (100, 128)           384         ['lambda[0][0]']
#
#  dense_5 (Dense)                (100, 256)           33024       ['dense_4[0][0]']
#
#  dense_6 (Dense)                (100, 784)           201488      ['dense_5[0][0]']
#
#  tf.math.square (TFOpLambda)    (None, 2)            0           ['dense_2[0][0]']
#
#  tf.math.exp (TFOpLambda)       (None, 2)            0           ['dense_3[0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 2)           0           ['tf.math.square[0][0]',
#  da)                                                              'tf.math.exp[0][0]']
#
#  tf.cast (TFOpLambda)           (None, 784)          0           ['input_1[0][0]']
#
#  tf.convert_to_tensor (TFOpLamb  (100, 784)          0           ['dense_6[0][0]']
#  da)
#
#  tf.math.subtract (TFOpLambda)  (None, 2)            0           ['tf.__operators__.add[0][0]',
#                                                                   'dense_3[0][0]']
#
#  tf.keras.backend.binary_crosse  (100, 784)          0           ['tf.cast[0][0]',
#  ntropy (TFOpLambda)                                              'tf.convert_to_tensor[0][0]']
#
#  tf.math.subtract_1 (TFOpLambda  (None, 2)           0           ['tf.math.subtract[0][0]']
#  )
#
#  tf.math.reduce_mean (TFOpLambd  (100,)              0           ['tf.keras.backend.binary_crossen
#  a)                                                              tropy[0][0]']
#
#  tf.math.reduce_sum (TFOpLambda  (None,)             0           ['tf.math.subtract_1[0][0]']
#  )
#
#  tf.math.multiply (TFOpLambda)  (100,)               0           ['tf.math.reduce_mean[0][0]']
#
#  tf.math.multiply_1 (TFOpLambda  (None,)             0           ['tf.math.reduce_sum[0][0]']
#  )
#
#  tf.__operators__.add_1 (TFOpLa  (100,)              0           ['tf.math.multiply[0][0]',
#  mbda)                                                            'tf.math.multiply_1[0][0]']
#
#  add_loss (AddLoss)             (100,)               0           ['tf.__operators__.add_1[0][0]']
#
# ==================================================================================================
# Total params: 469,268
# Trainable params: 469,268
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## 訓練模型

# %%
# 訓練模型
vae.fit(x_tr,
       shuffle=True,
       epochs=n_epoch,
       batch_size=batch_size,
       validation_data=(x_te, None), verbose=1)
# Out:
# Epoch 1/100
# 600/600 [==============================] - 11s 9ms/step - loss: 193.9967 - val_loss: 166.8575
# Epoch 2/100
# 600/600 [==============================] - 3s 5ms/step - loss: 163.3853 - val_loss: 160.1505
# Epoch 3/100
# 600/600 [==============================] - 5s 8ms/step - loss: 156.9368 - val_loss: 154.4293
# Epoch 4/100
# 600/600 [==============================] - 3s 5ms/step - loss: 152.6216 - val_loss: 150.8807
# Epoch 5/100
# 600/600 [==============================] - 3s 5ms/step - loss: 149.8642 - val_loss: 149.1730
# Epoch 6/100
# 600/600 [==============================] - 3s 5ms/step - loss: 147.8404 - val_loss: 147.3861
# Epoch 7/100
# 600/600 [==============================] - 4s 6ms/step - loss: 146.3073 - val_loss: 146.2813
# Epoch 8/100
# 600/600 [==============================] - 3s 6ms/step - loss: 145.1172 - val_loss: 145.7760
# Epoch 9/100
# 600/600 [==============================] - 3s 5ms/step - loss: 144.1533 - val_loss: 144.5651
# Epoch 10/100
# 600/600 [==============================] - 3s 6ms/step - loss: 143.3212 - val_loss: 144.1163
# Epoch 11/100
# 600/600 [==============================] - 3s 5ms/step - loss: 142.6752 - val_loss: 142.8718
# Epoch 12/100
# 600/600 [==============================] - 3s 5ms/step - loss: 142.0654 - val_loss: 142.4756
# Epoch 13/100
# 600/600 [==============================] - 3s 5ms/step - loss: 141.5224 - val_loss: 142.7843
# Epoch 14/100
# 600/600 [==============================] - 4s 6ms/step - loss: 141.2474 - val_loss: 142.1736
# Epoch 15/100
# 600/600 [==============================] - 3s 5ms/step - loss: 140.7845 - val_loss: 141.2449
# Epoch 16/100
# 600/600 [==============================] - 3s 4ms/step - loss: 140.4094 - val_loss: 141.9317
# Epoch 17/100
# 600/600 [==============================] - 3s 5ms/step - loss: 140.2137 - val_loss: 141.3433
# Epoch 18/100
# 600/600 [==============================] - 4s 6ms/step - loss: 139.8608 - val_loss: 141.2623
# Epoch 19/100
# 600/600 [==============================] - 4s 7ms/step - loss: 139.6395 - val_loss: 141.2796
# Epoch 20/100
# 600/600 [==============================] - 5s 8ms/step - loss: 139.7506 - val_loss: 141.1393
# 600/600 [==============================] - 5s 8ms/step - loss: 134.5816 - val_loss: 139.0942
# Epoch 84/100
# 600/600 [==============================] - 4s 7ms/step - loss: 134.8579 - val_loss: 138.4624
# Epoch 85/100
# 600/600 [==============================] - 5s 8ms/step - loss: 134.4954 - val_loss: 138.3414
# Epoch 86/100
# 600/600 [==============================] - 3s 5ms/step - loss: 134.3722 - val_loss: 137.8940
# Epoch 87/100
# 600/600 [==============================] - 3s 5ms/step - loss: 134.3360 - val_loss: 138.3357
# Epoch 88/100
# 600/600 [==============================] - 3s 4ms/step - loss: 134.1507 - val_loss: 137.7035
# Epoch 89/100
# 600/600 [==============================] - 3s 5ms/step - loss: 134.2419 - val_loss: 138.5537
# Epoch 90/100
# 600/600 [==============================] - 3s 5ms/step - loss: 134.1638 - val_loss: 138.2304
# Epoch 91/100
# 600/600 [==============================] - 4s 6ms/step - loss: 134.3419 - val_loss: 137.7053
# Epoch 92/100
# 600/600 [==============================] - 3s 6ms/step - loss: 134.3863 - val_loss: 138.3484
# Epoch 93/100
# 600/600 [==============================] - 3s 5ms/step - loss: 134.3985 - val_loss: 138.6499
# Epoch 94/100
# 600/600 [==============================] - 3s 5ms/step - loss: 134.3350 - val_loss: 137.7755
# Epoch 95/100
# 600/600 [==============================] - 4s 6ms/step - loss: 134.1520 - val_loss: 138.8083
# Epoch 96/100
# 600/600 [==============================] - 3s 6ms/step - loss: 134.5706 - val_loss: 137.9176
# Epoch 97/100
# 600/600 [==============================] - 3s 5ms/step - loss: 134.4151 - val_loss: 138.2127
# Epoch 98/100
# 600/600 [==============================] - 3s 5ms/step - loss: 134.1226 - val_loss: 138.3224
# Epoch 99/100
# 600/600 [==============================] - 4s 6ms/step - loss: 134.1240 - val_loss: 138.1721
# Epoch 100/100
# 600/600 [==============================] - 4s 7ms/step - loss: 134.2809 - val_loss: 138.3261

# %% [markdown]
# ## 取得編碼器的輸出，以測試資料預測，以編碼器的輸出繪圖

# %%
# 取得編碼器的輸出 mu
encoder = Model(x, mu)
encoder.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 784)]             0
#
#  dense (Dense)               (None, 256)               200960
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dense_2 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 234,114
# Trainable params: 234,114
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 以測試資料預測，以編碼器的輸出繪圖
x_te_latent = encoder.predict(x_te, batch_size=batch_size)
plt.figure(figsize=(6, 6))
plt.scatter(x_te_latent[:, 0], x_te_latent[:, 1], c=y_te)
plt.colorbar()
plt.show()
# Out:
# 100/100 [==============================] - 0s 2ms/step

# %% [markdown]
# ## 取得解碼器的輸出，以測試資料預測，以解碼器的輸出圖像

# %%
# 取得解碼器的輸出
decoder_input = Input(shape=(z_dim,))
_z_decoded = z_decoder1(decoder_input)
_z_decoded = z_decoder2(_z_decoded)
_y = y_decoder(_z_decoded)
generator = Model(decoder_input, _y)
generator.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 2)]               0
#
#  dense_4 (Dense)             multiple                  384
#
#  dense_5 (Dense)             multiple                  33024
#
#  dense_6 (Dense)             multiple                  201488
#
# =================================================================
# Total params: 234,896
# Trainable params: 234,896
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 顯示 2D manifold 
n = 15           # 顯示 15x15 視窗
digit_size = 28  # 圖像尺寸
figure = np.zeros((digit_size * n, digit_size * n))

# 
grid_x = norm.ppf(np.linspace(0.05, 0.95, n)) 
grid_y = norm.ppf(np.linspace(0.05, 0.95, n))

# 取得各種機率下的生成的樣本
for i, yi in enumerate(grid_x):
    for j, xi in enumerate(grid_y):
        z_sample = np.array([[xi, yi]])
        x_decoded = generator.predict(z_sample)
        digit = x_decoded[0].reshape(digit_size, digit_size)
        figure[i * digit_size: (i + 1) * digit_size,
               j * digit_size: (j + 1) * digit_size] = digit

plt.figure(figsize=(10, 10))
plt.imshow(figure, cmap='Greys_r')
plt.show()
# Out:
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 249ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 204ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 1s 552ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 207ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 1s 626ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 1s 569ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 1s 750ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
