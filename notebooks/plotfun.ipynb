# %% [markdown]
# <a href="https://colab.research.google.com/github/jumbokh/csu1111-class/blob/main/notebooks/plotfun.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np
import math

# %%
def g(x):
  return x**2-math.exp(x/2)
g2 = np.vectorize(g)
x = np.linspace(-2,2,1000)

# %%
plt.plot(x, g2(x), '-r', label='y=x^2-e^(x/2)')
plt.title('Graph of y=x^2-e^(x/2)')
plt.xlabel('x', color='#1C2833')
plt.ylabel('y', color='#1C2833')
plt.legend(loc='upper left')
plt.grid()
plt.show()

# %%
def g1(x):
  return x**3-3*(x**2)+4/3
g3 = np.vectorize(g1)
x = np.linspace(0,2,100)

# %%
plt.plot(x, g3(x), '-r', label='y=x^3-3x^2+4/3')
plt.title('Graph of y=x^3-3x^2+4/3')
plt.xlabel('x', color='#1C2833')
plt.ylabel('y', color='#1C2833')
plt.legend(loc='upper left')
plt.grid()
plt.show()

# %%
def g11(x):
  return x**3-3*(x**2)+8/3
g33 = np.vectorize(g11)
x = np.linspace(0,2,100)

# %%
plt.plot(x, g33(x), '-r', label='y=x^3-3x^2+8/3')
plt.title('Graph of y=x^3-3x^2+8/3')
plt.xlabel('x', color='#1C2833')
plt.ylabel('y', color='#1C2833')
plt.legend(loc='upper left')
plt.grid()
plt.show()

# %%
def g22(x):
  return (x**2-5)**2*(x**2-3)
g33 = np.vectorize(g22)
x = np.linspace(1.5,2.5,1000)

# %%
plt.plot(x, g33(x), '-r', label='y=(x^2-5)^2*(x^2-3)')
plt.title('Graph of y=(x^2-5)^2*(x^2-3)')
plt.xlabel('x', color='#1C2833')
plt.ylabel('y', color='#1C2833')
plt.legend(loc='upper left')
plt.grid()
plt.show()

# %%
def g44(x):
  return x**3-3*x**2+x+3
g55 = np.vectorize(g44)
x = np.linspace(-3,5,1000)

# %%
plt.plot(x, g55(x), '-r', label='y=x^3-3x^2+x+3')
plt.title('Graph of y=x^3-3x^2+x+3')
plt.xlabel('x', color='#1C2833')
plt.ylabel('y', color='#1C2833')
plt.legend(loc='upper left')
plt.grid()
plt.show()

# %%
def g66(x):
  return x**3-6
g77 = np.vectorize(g66)
x = np.linspace(-3,5,1000)

# %%
plt.plot(x, g77(x), '-r', label='y=x^3-6')
plt.title('Graph of y=x^3-6')
plt.xlabel('x', color='#1C2833')
plt.ylabel('y', color='#1C2833')
plt.legend(loc='upper left')
plt.grid()
plt.show()
